# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import matplotlib as plt
import seaborn as sns

print("Python version is "+sys.version)
#print("Matplotlib version is "+plt.__version__)
print("Numpy version is "+np.__version__)
print("Pandas version is "+pd.__version__)
# Out:
# Python version is 3.11.13 (main, Jun  5 2025, 08:14:07) [Clang 14.0.6 ]
# Numpy version is 2.4.3
# Pandas version is 3.0.1

# %% [markdown]
# ##Load Dataset

# %%
df = pd.read_csv("data/superstore.csv", encoding='latin1') 

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ##Check dataset

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %% [markdown]
# ##check for missing values

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# Total revenue

# %%
total_sale = df["Sales"].sum()
print(total_sale)
# Out:
# 2297200.8603

# %% [markdown]
# ##Top 10 products

# %%
top_prods = df.groupby("Sub-Category")["Sales"].sum().sort_values(ascending=False)
top_prods.head(10)
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Name: Sales, dtype: float64

# %% [markdown]
# ##Sales by Region

# %%
sales_region = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
sales_region
# Out:
# Region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# South      391721.9050
# Name: Sales, dtype: float64

# %% [markdown]
# ##Monthly Sales Trend

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Month"] = df["Order Date"].dt.to_period("M")

monthly_sales = df.groupby("Month")["Sales"].sum()

monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.show()

# %% [markdown]
# ##Top 10 Products Chart

# %%
top_prods.head(10).plot(kind="bar")

plt.title("Top Selling Products")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ##Insights

# %% [markdown]
# The West region produces the most sales while the South produces the least amount of sales.
# Sales significantly increase from Jan 2017 and drop again after November 2017.
# Phones and chairs sell significatly more than the rest of the products.
